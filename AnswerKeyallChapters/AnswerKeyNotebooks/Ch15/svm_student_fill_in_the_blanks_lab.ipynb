# %% [markdown]
# # Support Vector Machine (SVM) Lab
# ## Student Fill-in-the-Blanks Notebook
#
# **Objective:** Build a classification model using Support Vector Machine (SVM) to predict customer purchase behavior.
#
# **Dataset features:**
# - Age
# - Income
#
# **Target:**
# - Purchase (0 = No, 1 = Yes)

# %% [markdown]
# ## Step 1: Import Libraries
#
# Fill in the blanks to import the required libraries.

# %%
import numpy as ____
import pandas as ____
import matplotlib.pyplot as ____
from sklearn.model_selection import ____
from sklearn.svm import ____
from sklearn.preprocessing import ____
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ## Step 2: Create the Dataset
#
# Complete the code to create a pandas DataFrame.

# %%
data = {
    "Age": [25, 35, 45, 20, 30, 22, 40, 28, 50, 23],
    "Income": [30, 60, 65, 20, 45, 25, 70, 48, 80, 27],
    "Purchase": [0, 1, 1, 0, 1, 0, 1, 1, 1, 0]
}

df = pd.____(data)
df

# %% [markdown]
# ## Step 3: Define Features and Target

# %%
X = df[["____", "____"]]
y = df["____"]

print("Features:")
print(X.head())
print("\nTarget:")
print(y.head())

# %% [markdown]
# ## Step 4: Split the Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=____, random_state=____
)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))

# %% [markdown]
# ## Step 5: Feature Scaling
#
# SVM works better when numerical features are scaled.

# %%
scaler = StandardScaler()

X_train = scaler.____(X_train)
X_test = scaler.____(X_test)

# %% [markdown]
# ## Step 6: Train the SVM Model
#
# Use a linear kernel first.

# %%
model = SVC(kernel="____")
model.fit(____, ____)

# %% [markdown]
# ## Step 7: Make Predictions

# %%
y_pred = model.____(X_test)
print("Predictions:", y_pred)

# %% [markdown]
# ## Step 8: Evaluate the Model

# %%
print("Accuracy:", accuracy_score(____, ____))
print("\nConfusion Matrix:\n", confusion_matrix(____, ____))
print("\nClassification Report:\n", classification_report(____, ____))

# %% [markdown]
# ## Step 9: Visualize the Dataset
#
# This plot shows the original data distribution.

# %%
plt.figure(figsize=(7, 5))
plt.scatter(df["Age"], df["Income"], c=df["Purchase"])
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Customer Purchase Dataset")
plt.show()

# %% [markdown]
# ## Practice Tasks
#
# 1. Change the kernel from `linear` to `rbf`.
# 2. Try a polynomial kernel.
# 3. Change the test size.
# 4. Add more rows to the dataset and observe the results.
# 5. Compare model performance with and without scaling.
