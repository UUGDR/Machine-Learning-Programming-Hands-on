# %% [markdown]
# # ANN-Based Customer Churn Prediction
# ## Student Fill-in-the-Blanks Notebook
#
# In this notebook, you will build a simple **Artificial Neural Network (ANN)** model for **customer churn prediction** using a customer churn dataset.
#
# Complete the missing parts marked with **______**.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import ______ as np
import ______ as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import _____________
from sklearn.preprocessing import _____________, _____________
from sklearn.compose import ______________
from sklearn.metrics import _____________, _____________, _____________, _____________, _____________, _____________

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import _________, _________

# %% [markdown]
# ## 2. Load the Dataset

# %%
df = pd.read_csv("________________________")
df.head()

# %%
df.shape

# %%
df.info()

# %% [markdown]
# ## 3. Explore the Target Variable

# %%
df["__________"].value_counts()

# %%
sns.countplot(x="__________", data=df)
plt.title("Customer Churn Distribution")
plt.show()

# %% [markdown]
# ## 4. Drop Unnecessary Columns

# %%
df = df.drop(["____________"], axis=1)
df.head()

# %% [markdown]
# ## 5. Check Missing Values

# %%
df.isnull().sum()

# %%
df = df.dropna()

# %% [markdown]
# ## 6. Separate Features and Target

# %%
X = df.drop("__________", axis=1)
y = df["__________"]

# %% [markdown]
# ## 7. Convert Target Variable to Numeric

# %%
y = y.map({"No": __, "Yes": __})
y.head()

# %% [markdown]
# ## 8. Identify Numerical and Categorical Columns

# %%
cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

print("Categorical columns:", cat_cols)
print("Numerical columns:", num_cols)

# %% [markdown]
# ## 9. Create Preprocessing Pipeline

# %%
preprocessor = ColumnTransformer([
    ("num", ____________(), num_cols),
    ("cat", ____________(handle_unknown="ignore"), cat_cols)
])

# %% [markdown]
# ## 10. Split the Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=____,
    random_state=____,
    stratify=____
)

# %% [markdown]
# ## 11. Apply Preprocessing

# %%
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# %%
X_train_processed.shape, X_test_processed.shape

# %% [markdown]
# ## 12. Build the ANN Model

# %%
model = Sequential([
    Dense(____, activation="________", input_shape=(X_train_processed.shape[1],)),
    Dropout(____),
    Dense(____, activation="________")
])

# %% [markdown]
# ## 13. Compile the Model

# %%
model.compile(
    optimizer="__________",
    loss="__________________",
    metrics=["__________"]
)

# %% [markdown]
# ## 14. Train the Model

# %%
history = model.fit(
    X_train_processed,
    y_train,
    epochs=____,
    batch_size=____,
    validation_split=____,
    verbose=1
)

# %% [markdown]
# ## 15. Plot Accuracy

# %%
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## 16. Plot Loss

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Model Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 17. Make Predictions

# %%
y_pred_prob = model.predict(X_test_processed)
y_pred = (y_pred_prob > ____).astype(int)

y_pred[:5]

# %% [markdown]
# ## 18. Evaluate the Model

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Purples")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## 19. Interpretation Questions
#
# Fill in the blanks:
#
# 1. The activation function used in the output layer is **____________**.
# 2. The loss function used for binary classification is **____________**.
# 3. One-hot encoding is used for **____________** features.
# 4. StandardScaler is used for **____________** features.
# 5. Churn prediction is useful because **__________________________________________**.

# %% [markdown]
# ## 20. Conclusion
#
# Complete the conclusion below:
#
# In this notebook, we built a **______________________** model for **______________________** prediction.
# We first loaded the dataset, then preprocessed the features, and finally trained a **______________________** neural network.
# The model was evaluated using **______________________, ______________________, and ______________________**.
