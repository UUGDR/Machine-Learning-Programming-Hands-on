# %% [markdown]
# # KNN Hands-on Lab (Fill in the Blanks)
#
# In this lab, you will implement **K-Nearest Neighbors (KNN)** classification using the **Iris dataset**.
#
# ## Dataset Reference
# - R. A. Fisher, *The Use of Multiple Measurements in Taxonomic Problems*, 1936.
# - Iris dataset is packaged with scikit-learn: `sklearn.datasets.load_iris()`.
#
# ## Learning goals
# 1. Load a dataset and inspect features/labels
# 2. Split into train/test sets
# 3. Train a KNN classifier
# 4. Evaluate accuracy and confusion matrix
# 5. Tune K and visualize accuracy vs K

# %% [markdown]
# ## Step 1: Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import _______
from sklearn.model_selection import _______
from sklearn.preprocessing import _______
from sklearn.neighbors import _______
from sklearn.pipeline import _______
from sklearn.metrics import _______, confusion_matrix, classification_report

# %% [markdown]
# ## Step 2: Load Iris dataset

# %%
iris = _______()
X = iris.______
y = iris.______

print("Feature matrix shape:", X.shape)
print("Labels shape:", y.shape)
print("Target names:", iris.target_names)

# %% [markdown]
# ## Step 3: Preview the data

# %%
df = pd.DataFrame(______, columns=iris.feature_names)
df["target"] = ______
df.head()

# %% [markdown]
# ## Step 4: Split into train and test sets

# %%
X_train, X_test, y_train, y_test = _______(
    X, y, test_size=__, random_state=__, stratify=__
)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)

# %% [markdown]
# ## Step 5: Build and train a scaled KNN model

# %%
k = __
model = make_pipeline(
    _______(),
    _______(n_neighbors=k)
)

model.fit(______, ______)

# %% [markdown]
# ## Step 6: Predict and evaluate

# %%
y_pred = model._______(X_test)

acc = _______(y_test, y_pred)
print("Accuracy:", acc)

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=iris.target_names))

# %% [markdown]
# ## Step 7: Tune K (simple search)

# %%
ks = list(range(1, __, __))
scores = []

for k in ks:
    m = make_pipeline(_______(), _______(n_neighbors=k))
    m.fit(______, ______)
    pred = m._______(X_test)
    scores.append(_______(y_test, pred))

best_k = ks[int(np.argmax(scores))]
best_score = float(np.max(scores))

print("Best K:", best_k)
print("Best accuracy:", best_score)

# %% [markdown]
# ## Step 8: Plot accuracy vs K

# %%
plt.figure(figsize=(7,4.5))
plt.plot(ks, scores, marker="o", linewidth=__, color="______")
plt.title("Accuracy vs K", fontsize=14, color="______")
plt.xlabel("K (number of neighbors)")
plt.ylabel("Accuracy")
plt.grid(True, alpha=0.2)
plt.show()
