# %% [markdown]
# # Matplotlib Hands-On Exercises (Student Version)
#
# Fill in the blanks to complete the exercises.

# %% [markdown]
# ## Exercise 1 — Install Matplotlib

# %%
# !____ install matplotlib

# %% [markdown]
# ## Exercise 2 — Import Libraries

# %%
import ____ as pd
import ____________.pyplot as plt

# %% [markdown]
# ## Exercise 3 — Load Dataset

# %%
from io import StringIO

data = StringIO("""speed,dist
4,2
4,10
7,4
7,22
8,16
9,10
10,18
10,26
11,17
11,28
12,14
12,20
13,26
13,34
14,46
15,26
15,36
16,32
16,40
17,32
17,40
18,42
18,56
19,76
20,48
20,52
22,84
23,92
24,93
24,120
""")

cars = pd.read_csv(______)
cars.______()

# %% [markdown]
# ## Exercise 4 — Create Speed Groups

# %%
bins = [____, ____, ____, ____, ____]
labels = ["0–10", "11–15", "16–20", "21+"]

cars["speed_group"] = pd.________(cars["speed"], bins=bins, labels=labels)

# %% [markdown]
# ## Exercise 5 — Bar Chart

# %%
group_avg = cars.________("speed_group")["dist"].________()

plt.________(group_avg.index, group_avg.values)
plt.title("____________")
plt.show()

# %% [markdown]
# ## Exercise 6 — Histogram

# %%
plt.________(cars["______"], bins=__)
plt.show()

# %% [markdown]
# ## Exercise 7 — Pie Chart

# %%
group_counts = cars["________"].________()

plt.________(group_counts.values, labels=group_counts.index)
plt.show()
