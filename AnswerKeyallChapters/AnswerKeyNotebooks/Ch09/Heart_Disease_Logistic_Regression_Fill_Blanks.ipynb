# %% [markdown]
# # Heart Disease Prediction Lab: Fill in the Blanks
#
# **Dataset:** UCI Heart Disease Dataset (Cleveland subset commonly used)
#
# **Target variable:** `num` (0–4)
#
# For this lab, convert to binary:
# - `0` = No heart disease
# - `1` = Presence of heart disease (values 1–4)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import ______ as pd
import ______ as np

from sklearn.model_selection import __________
from sklearn.preprocessing import __________
from sklearn.linear_model import __________
from sklearn.metrics import __________, __________, __________, __________
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Load Dataset

# %%
# Replace the file name with your actual dataset path if needed
df = pd.__________("heart.csv")
df.__________()

# %% [markdown]
# ## Step 3: Define Binary Target

# %%
# Convert num (0-4) into a binary target
df['target'] = df['num'].apply(lambda x: ___ if x == 0 else ___)

# Drop the original target column
df = df.__________('num', axis=1)

df.__________()

# %% [markdown]
# ## Step 4: Data Cleaning

# %%
# Check missing values
print(df.__________().sum())

# Drop missing values
df = df.__________()

print("\nDataset shape after cleaning:", df.shape)

# %% [markdown]
# ## Step 5: Train-Test Split

# %%
X = df.__________('target', axis=1)
y = df['__________']

X_train, X_test, y_train, y_test = __________(
    X, y, test_size=____, random_state=____
)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)

# %% [markdown]
# ## Step 6: Feature Scaling

# %%
scaler = __________()

X_train = scaler.__________(X_train)
X_test = scaler.__________(X_test)

# %% [markdown]
# ## Step 7: Train Logistic Regression

# %%
model = __________(max_iter=____)
model.__________(X_train, y_train)

y_pred = model.__________(X_test)
y_prob = model.__________(X_test)[:, 1]

# %% [markdown]
# ## Step 8: Model Evaluation

# %%
cm = __________(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

print("\nClassification Report:")
print(__________(y_test, y_pred))

# %% [markdown]
# ## Plot ROC Curve Using Matplotlib

# %%
fpr, tpr, thresholds = __________(y_test, y_prob)
roc_auc = __________(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel("________________________")
plt.ylabel("________________________")
plt.title("________________________")
plt.legend()
plt.grid(True)
plt.show()
