# %% [markdown]
# # AI 240 – Pandas Exercise Lab (Student Version)
# Fill in the blanks and run each cell.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Step 1: Load Dataset

# %%
df = _______________________
print(df.shape)
print(df.columns)

# %% [markdown]
# ## Step 2: View Data

# %%
df.__________()
df.__________()

# %% [markdown]
# ## Step 3: Filter Rows

# %%
col = __________________
threshold = df[col].__________()
df_filtered = df[df[col] > threshold]

# %% [markdown]
# ## Step 4: Select Columns

# %%
df_small = df[[__________, __________]]

# %% [markdown]
# ## Step 5: Handle Missing Values

# %%
df.isna().sum()
df_clean = df.__________()

# %% [markdown]
# ## Step 6: Group By

# %%
df.groupby(__________)[__________].mean()

# %% [markdown]
# ## Step 7: Sort

# %%
df.sort_values(by=__________, ascending=False)

# %% [markdown]
# ## Step 8: Merge

# %%
df2 = pd.DataFrame({'id': df.index})
df_merged = df.merge(df2, on='id')

# %% [markdown]
# ## Step 9: Apply Function

# %%
df['new_col'] = df[__________].apply(lambda x: __________)
